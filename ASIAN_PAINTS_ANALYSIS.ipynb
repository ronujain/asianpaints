# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel(r'D:\ALPHABATCH\BALANCE-SHEET\asianpaintsp&l.xlsx')

# %%
df
# Out:
#     Unnamed: 0                   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN                          NaN        NaN        NaN        NaN
# 1          NaN                       Income        NaN        NaN        NaN
# 2          NaN               Sales Turnover    30078.4   25188.51   18516.86
# 3          NaN                    Net Sales    30078.4   25188.51   18516.86
# 4          NaN                 Other Income     518.01     398.16     366.02
# 5          NaN            Stock Adjustments     299.74    1208.63       90.7
# 6          NaN                 Total Income   30896.15    26795.3   18973.58
# 7          NaN                  Expenditure        NaN        NaN        NaN
# 8          NaN                Raw Materials    18708.3    16885.8   10225.51
# 9          NaN            Power & Fuel Cost     122.15     104.66      74.71
# 10         NaN                Employee Cost    1513.89    1310.14    1128.66
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#                      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                           NaN        NaN        NaN        NaN        NaN
# 1                        Income        NaN        NaN        NaN        NaN
# 2                Sales Turnover    30078.4   25188.51   18516.86   17194.09
# 3                     Net Sales    30078.4   25188.51   18516.86   17194.09
# 4                  Other Income     518.01     398.16     366.02     314.52
# 5             Stock Adjustments     299.74    1208.63       90.7     210.21
# 6                  Total Income   30896.15    26795.3   18973.58   17718.82
# 7                   Expenditure        NaN        NaN        NaN        NaN
# 8                 Raw Materials    18708.3    16885.8   10225.51    9770.18
# 9             Power & Fuel Cost     122.15     104.66      74.71       83.3
# 10                Employee Cost    1513.89    1310.14    1128.66     985.43
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 2               Sales Turnover    30078.4   25188.51   18516.86   17194.09
# 3                    Net Sales    30078.4   25188.51   18516.86   17194.09
# 4                 Other Income     518.01     398.16     366.02     314.52
# 5            Stock Adjustments     299.74    1208.63       90.7     210.21
# 6                 Total Income   30896.15    26795.3   18973.58   17718.82
# 8                Raw Materials    18708.3    16885.8   10225.51    9770.18
# 9            Power & Fuel Cost     122.15     104.66      74.71       83.3
# 10               Employee Cost    1513.89    1310.14    1128.66     985.43
# 11  Selling and Admin Expenses     1012.3     804.64     691.85     782.53
# 12      Miscellaneous Expenses    3201.02    2704.11    1994.05    1925.82
# 13              Total Expenses   24557.66   21809.35   14114.78   13547.26
# ...

# %%
df.rename(columns={'Unnamed: 1':'Particular','Unnamed: 2':'2023','Unnamed: 3':'2022','Unnamed: 4':'2021','Unnamed: 5':'2020','Unnamed: 6':'2019'})
# Out:
#                     Particular      2023      2022      2021      2020  \
# 2               Sales Turnover   30078.4  25188.51  18516.86  17194.09
# 3                    Net Sales   30078.4  25188.51  18516.86  17194.09
# 4                 Other Income    518.01    398.16    366.02    314.52
# 5            Stock Adjustments    299.74   1208.63      90.7    210.21
# 6                 Total Income  30896.15   26795.3  18973.58  17718.82
# 8                Raw Materials   18708.3   16885.8  10225.51   9770.18
# 9            Power & Fuel Cost    122.15    104.66     74.71      83.3
# 10               Employee Cost   1513.89   1310.14   1128.66    985.43
# 11  Selling and Admin Expenses    1012.3    804.64    691.85    782.53
# 12      Miscellaneous Expenses   3201.02   2704.11   1994.05   1925.82
# 13              Total Expenses  24557.66  21809.35  14114.78  13547.26
# 18            Operating Profit   5820.48   4587.79   4492.78   3857.04
# ...

# %%
year = ['2023', '2022', '2021', '2020','2019']
sales = [30596.41,25640.40,18882.88,17551.63,16676.59]

plt.bar(year, sales)

plt.xlabel('year')
plt.ylabel('sales')
plt.title('Bar Plot Example')

plt.show()

# %%
year = ['2023', '2022', '2021', '2020','2019']
sales = [30596,25640,18882,17551,16676]
for i in range(len(sales) - 1):
    total = sales[i]-sales[i+1]
    percentage = (total/sales[i])*100
    per=int( percentage)
    print("Sales percentage for year " + year[i+1] + " is " + str(per) + "%")
# Out:
# Sales percentage for year 2022 is 16%
# Sales percentage for year 2021 is 26%
# Sales percentage for year 2020 is 7%
# Sales percentage for year 2019 is 4%

# %% [markdown]
# # HERE WE FIND THAT IN 2021 THE AVERAGE SALES IS INCREASE BY 26%
# # THAT MEANS HIGEST SALES IN 2021 IN 5 YR DATA
# # SO POSSIBILITY OF INCREASE IN PROFIT ALSO
# # LET'S FIND WHAT HAPPEN

# %%
year = ['2023', '2022', '2021', '2020','2019']
profit = [4100.18, 3134.71 , 3051.8 , 2653.95 , 2132.17]

plt.bar(year, profit)


plt.xlabel('year')
plt.ylabel('profit')
plt.title('Bar Plot Example')

plt.show()

# %%
year = ['2023', '2022', '2021', '2020','2019']
profit = [4100.18, 3134.71 , 3051.8 , 2653.95 , 2132.17]
for i in range(len(profit) - 1):
    total = profit[i]-profit[i+1]
    percentage = (total/profit[i])*100
    per=int( percentage)
    print(" Net Profit percentage for year " + year[i+1] + " is " + str(per) + "%")
# Out:
#  Net Profit percentage for year 2022 is 23%
#  Net Profit percentage for year 2021 is 2%
#  Net Profit percentage for year 2020 is 13%
#  Net Profit percentage for year 2019 is 19%

# %% [markdown]
# # HERE YOU CAN SEE THE PROFIT IS JUST INCREASED BY 2% ONLY . WHICH IS LOWEST IN 5 YR AND SIMULTANSILY THE SALES IS INCREASED BY 26%
# # WHICH IS HIGEST IN THE 5YR  LETS'S FIND WHAT'S HAPPEN THAT THE PROFIT IS DECREAES TOO MUCH

# %%
year = ['2023', '2022', '2021', '2020','2019']
Total_Expenses = [24557.66,21809.35,14114.78,13547.26,13134.83]

plt.bar(year, Total_Expenses)


plt.xlabel('year')
plt.ylabel('Total_Expenses')
plt.title('Bar Plot Example')


plt.show()

# %%
year = ['2023', '2022', '2021', '2020','2019']
Total_Expenses = [24557.66,21809.35,14114.78,13547.26,13134.83]
for i in range(len(Total_Expenses) - 1):
    total = Total_Expenses[i]-Total_Expenses[i+1]
    percentage = (total/Total_Expenses[i])*100
    per=int( percentage)
    print("Sales percentage for year " + year[i+1] + " is " + str(per) + "%")
# Out:
# Sales percentage for year 2022 is 11%
# Sales percentage for year 2021 is 35%
# Sales percentage for year 2020 is 4%
# Sales percentage for year 2019 is 3%

# %% [markdown]
# # AND HERE THE EXPENSES IS INCREASED BY 35% WHICH MEANS THE MAJOR PART OF PROFIT IS TAKEN BY EXPENSES NOW WE HAVE TO TAKE A LOOK
# # WHERE THE MOST EXPENSES PART GOES TO

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # SO I   ANALYSED THE CASHFLOW STATEMENT OF THE COMPANY

# %%
cashflow = pd.read_excel(r'D:\ALPHABATCH\BALANCE-SHEET\cahflow.xlsx')

# %%
cashflow
# Out:
#     Unnamed: 0  Unnamed: 1                                         Unnamed: 2  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                                NaN
# 2          NaN         NaN             CASH FLOW OF ASIAN PAINTS (in Rs. Cr.)
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN  NET PROFIT/LOSS BEFORE EXTRAORDINARY ITEMS AND...
# 5          NaN         NaN             Net CashFlow From Operating Activities
# 6          NaN         NaN              Net Cash Used In Investing Activities
# 7          NaN         NaN            Net Cash Used From Financing Activities
# 8          NaN         NaN                    Foreign Exchange Gains / Losses
# 9          NaN         NaN  Adjustments On Amalgamation Merger Demerger Ot...
# 10         NaN         NaN           NET INC/DEC IN CASH AND CASH EQUIVALENTS
# ...

# %%
cashflow.drop('Unnamed: 0',axis=1,inplace=True)

# %%
cashflow.drop('Unnamed: 1',axis=1,inplace=True)

# %%
cashflow.dropna(inplace=True)

# %%
cashflow
# Out:
#                                            Unnamed: 2           Unnamed: 3  \
# 2              CASH FLOW OF ASIAN PAINTS (in Rs. Cr.)  2023-03-01 00:00:00
# 4   NET PROFIT/LOSS BEFORE EXTRAORDINARY ITEMS AND...              5688.83
# 5              Net CashFlow From Operating Activities              4193.43
# 6               Net Cash Used In Investing Activities             -1274.64
# 7             Net Cash Used From Financing Activities             -2140.05
# 8                     Foreign Exchange Gains / Losses                 -7.7
# 9   Adjustments On Amalgamation Merger Demerger Ot...                    0
# 10           NET INC/DEC IN CASH AND CASH EQUIVALENTS               771.04
# 11            Cash And Cash Equivalents Begin of Year              2283.29
# 12              Cash And Cash Equivalents End Of Year              3054.33
#
#              Unnamed: 4           Unnamed: 5           Unnamed: 6  \
# 2   2022-03-01 00:00:00  2021-03-01 00:00:00  2020-03-01 00:00:00
# ...

# %%
cashflow.rename(columns={'Unnamed: 2':'Particular','Unnamed: 3':'2023','Unnamed: 4':'2022','Unnamed: 5':'2021','Unnamed: 6':'2020','Unnamed: 7':'2019'})
# Out:
#                                            Particular                 2023  \
# 2              CASH FLOW OF ASIAN PAINTS (in Rs. Cr.)  2023-03-01 00:00:00
# 4   NET PROFIT/LOSS BEFORE EXTRAORDINARY ITEMS AND...              5688.83
# 5              Net CashFlow From Operating Activities              4193.43
# 6               Net Cash Used In Investing Activities             -1274.64
# 7             Net Cash Used From Financing Activities             -2140.05
# 8                     Foreign Exchange Gains / Losses                 -7.7
# 9   Adjustments On Amalgamation Merger Demerger Ot...                    0
# 10           NET INC/DEC IN CASH AND CASH EQUIVALENTS               771.04
# 11            Cash And Cash Equivalents Begin of Year              2283.29
# 12              Cash And Cash Equivalents End Of Year              3054.33
#
#                    2022                 2021                 2020  \
# 2   2022-03-01 00:00:00  2021-03-01 00:00:00  2020-03-01 00:00:00
# ...

# %%
year = ['2023', '2022', '2021', '2020','2019']
Operating_Activities = [4193.43,986.49,3683.35,3038.15,2469.54]

plt.bar(year, Operating_Activities)

plt.xlabel('year')
plt.ylabel('Operating_Activities')
plt.title('Bar Plot Example')

plt.show()

# %%
year = ['2023', '2022', '2021', '2020','2019']
Operating_Activities = [4193.43,986.49,3683.35,3038.15,2469.54]
for i in range(len(Operating_Activities) - 1):
    total = Operating_Activities[i]-Operating_Activities[i+1]
    percentage = (total/Operating_Activities[i])*100
    per=int( percentage)
    print("Operating Activities percentage for year " + year[i+1] + " is " + str(per) + "%")
# Out:
# Operating Activities percentage for year 2022 is 76%
# Operating Activities percentage for year 2021 is -273%
# Operating Activities percentage for year 2020 is 17%
# Operating Activities percentage for year 2019 is 18%

# %% [markdown]
# # Sales percentage for year 2021 is 26%
# # Net Profit percentage for year 2021 is 2%
# # Operating Activities percentage for year 2021 is -273%

# %%
#  materials used in the production of goods or services during a specific period. 
# When a company makes sales on credit and allows customers to pay at a later date, it creates trade receivables.

# %% [raw]
# # Revenue from sale of products
# #  Paints, décor and related products 24,582.94 18,009.26
# #  Bath Fittings and related products 352.63 243.20
# # Revenue from sale of services
# #  Painting, décor and related services 66.52 27.60
# # Other operating revenues
# #  Processing and service income 35.00 33.53
# #  Scrap sales 32.01 20.83
# # Other Income (Refer note 23(c)(ii))
# #  Royalty received from subsidiary and associate companies 73.07 62.07
# # Total 25,142.17 18,396.49
# # B. REVENUE FROM CONTRACTS WITH CUSTOMERS DISAGGREGATED BASED ON
# # GEOGRAPHY
# # Home market 24,929.20 18,277.74
# # Exports 212.97 118.75
# # Total 25,142.17 18,396.49

# %% [markdown]
# # (a) Raw materials 1,390.86 812.62
# Raw materials-in-transit 553.31 225.46
#  1,944.17 1,038.08
# (b) Packing materials 85.21 68.86
# (c) Work-in-progress 177.42 120.57
# (d) Finished goods 2,261.57 1,406.75
# Finished goods-in-transit - 0.71
#  2,261.57 1,407.46
# (e) Stock-in-trade (acquired for trading) 613.14 318.98
# Stock-in-trade (acquired for trading) in-transit 44.63 41.12
#  657.77 360.10
# (f) Stores, spares and consumables 151.47 129.00
# Stores, spares and consumables-in-transit - 0.54
#  151.47 129.54
# Total 5,277.61 3,124.61

# %% [markdown]
# # NOTE 10 : TRADE RECEIVABLES
# (` in Crores)
# Current
# As at
# 31.03.2022
# As at
# 31.03.2021
# Trade receivables - Unsecured*
# (a) Considered good 2,915.77 1809.75
# (b) Considered doubtful 94.38 58.19
#  3,010.15 1,867.94
#  Less: Allowance for doubtful debts (94.38) (58.19)
# Total 2,915.77 1,809.75
